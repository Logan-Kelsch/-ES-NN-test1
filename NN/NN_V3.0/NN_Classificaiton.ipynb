# %%
#JJ McCauley + LOGAN KELSCH 
#TEST NN 1

#IMPORT LIBRARIES-------------------------------------------------------

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from keras.optimizers import SGD
from keras.initializers import GlorotUniform
from keras.initializers import RandomNormal
from keras.callbacks import EarlyStopping
from imblearn.over_sampling import SMOTE

#hahaha dont turn this on with high epoch or else
#tf.config.experimental.set_memory_growth

#LOAD DATA FROM CSV-------------------------------------------------------

# Load the dataset
data = pd.read_csv('catted_1.csv')

#testing random feature drops
data = data.drop(columns='FT')
#data = data.drop(columns='FullK')
#data = data.drop(columns='diffKD')
#data = data.drop(columns='OB')
#data = data.drop(columns='OS')
#data = data.drop(columns='vol')
#data = data.drop(columns='s15')
#data = data.drop(columns='s30')
#data = data.drop(columns='s60')
#data = data.drop(columns='ToD')
#data = data.drop(columns='Inertias')
#data = data.drop(columns='percBB')
#data = data.drop(columns='spreadRSI')
#data = data.drop(columns='ADX')
#data = data.drop(columns='RSI')
#data = data.drop(columns='Wpercent')
#data = data.drop(columns='acc')

#TEMP DROP PRE-DUAL-OUTPUT NN

#data = data.drop(columns='bull15')
#data = data.drop(columns='bear15')
#data = data.drop(columns='bull30')
#data = data.drop(columns='bear30')
#data = data.drop(columns='bull60')
data = data.drop(columns='DIR')

#confirming X and Y features post training
Xfeatures = data.columns[:-1]
Yfeatures = data.columns[-1]
print("TESTED FEATURES: ")
print(Xfeatures)
print("TESTING FOR: ")
print(Yfeatures)

#DATA OPTIMIZATION------------------------------------------------------

print("OCCURANCES IN RAW DATA FOR ", Yfeatures, ": ", sep='')
unique, counts = np.unique(data.iloc[:, -1].values, return_counts=True)
print(dict(zip(unique,counts)))

#filtering before splitting could be useful if ABSOLUTELY mostly comprised of 'in'
#data = data.drop(data[data['ToD'] > 955].index)
#data = data.drop(data[data['ToD'] < 480].index)

NinRows = data.drop(data[data['MOVE'] == 'mv'].index)
inRows = data.drop(data[data['MOVE'] == 'nm'].index)

#CUSTOM DATA FILTERING_____________

#tod >955, <480 - MARKET OPEN
#inRows = inRows.drop(inRows[inRows['ToD'] > 955].index)
#inRows = inRows.drop(inRows[inRows['ToD'] < 455].index)
#inRows = inRows.drop(inRows[inRows['s60'] <0].index)
#inRows = inRows.drop(inRows[inRows['OB'] == 1].index)

#must drop these features in optData!!!!!!!!!!!
#__________________________________

inRowsMatch = inRows#inRows.loc[0:17129]

print('ins -\t',inRows.index.size,'\ninsMatch -\t',\
      inRowsMatch.index.size,'\nnon-ins -\t',NinRows.index.size)

optData = pd.concat([NinRows, inRowsMatch],axis=0)

#optData = optData.drop(columns='s60')
#optData = optData.drop(columns='ToD')
#optData = optData.drop(columns='OB')

percIn = data.size/(inRows.size*2)
percNin = data.size/(NinRows.size*2)
weight_for_0 = percIn
weight_for_1 = percNin
cw = {0: weight_for_0, 1: weight_for_1}

print("PERCENT & WEIGHTS:\nINS\t-\t",percIn*100," %\nNon-INS\t-\t",percNin*100," %",sep='')
print('\n\nActual Weights:\nweight_for_0: ',weight_for_0,'\nweight_for_1: ',weight_for_1,sep='',end='')

print('\nNin rows size = ',(NinRows.size/inRows.size*100),'% the size of In rows\n',sep='')

print("\n\nOCCURANCES IN OPT DATA FOR ", Yfeatures, ": ", sep='')
unique, counts = np.unique(optData.iloc[:, -1].values, return_counts=True)
print(dict(zip(unique,counts)))

#PROCESS THE DATA-------------------------------------------------------

# Separate features and target
X = optData.iloc[:, :-1].values
y = optData.iloc[:, -1].values

#SMOTE OVERSAMPLING________________

#smote = SMOTE()
#X, y = smote.fit_resample(X,y)
#print('\n[PRE-SPLIT] Resampled Data size:',X.size,'--',y.size)

#__________________________________

#Encoding data
labelencoder = LabelBinarizer()
y = labelencoder.fit_transform(y)

# Standardize the features
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) #stratify=y,
#RESAMPLED DATA- POST SPLIT---------------------------------------------------------

#smote = SMOTE()
#X_resampled, y_resampled = smote.fit_resample(X_train,y_train)
#print('\nResampled Data size:',X_resampled.size)

#BUILD THE NEURAL NETWORK MODEL-------------------------------------------------------

from keras.optimizers.schedules import ExponentialDecay
lr_schedule = ExponentialDecay(
    #good rough val to start, .25, good val to end at .0015.
    #5k epoch should be: .25, 8565, .9995, true
    0.01,
    decay_steps=1000,
    decay_rate=0.98,
    staircase=True)

opt1 = SGD(learning_rate=0.0001)
opt2  = tf.keras.optimizers.Adam(clipnorm=0.7)
opt3 = SGD(learning_rate=lr_schedule)

from keras.saving import get_custom_objects
from keras.saving import register_keras_serializable


get_custom_objects().clear()
@register_keras_serializable(name="custom_loss")
def custom_loss(y_true, y_pred):
        
    # Standard binary cross-entropy
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        
    # Define penalties for false negatives (y_true = 1, y_pred = 0)
    false_negatives_penalty = 0.0  # Penalty for false negatives
    false_positives_penalty = 0.0  # Penalty for false positives
        
    # Define reward for true positives (y_true = 1, y_pred = 1)
    true_positives_reward = -0.0  # Negative value to reduce the loss when TP happens

    # Calculate false negatives and false positives
    false_negatives = y_true * (1 - y_pred)
    false_positives = (1 - y_true) * y_pred
        
    # Calculate true positives
    true_positives = y_true * y_pred
        
    # Apply penalties and rewards
    penalties = false_negatives_penalty * false_negatives + false_positives_penalty * false_positives
    rewards = true_positives_reward * true_positives
        
    # Return combined loss (penalize FNs and FPs, reward TPs)
    return bce + penalties + rewards

def build_model():
    model = tf.keras.Sequential([#currently 17 total features
        tf.keras.layers.Dense(512, input_dim=37, activation='leaky_relu'),
        tf.keras.layers.Dropout(0.20),
        tf.keras.layers.Dense(512, activation='leaky_relu'),
        tf.keras.layers.Dropout(0.20),
        tf.keras.layers.Dense(512, activation='leaky_relu'),
        tf.keras.layers.Dropout(0.20),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    AUC=tf.keras.metrics.AUC(curve='PR')
    met = ['Accuracy','AUC',AUC,'Precision','Recall','TrueNegatives','TruePositives','FalsePositives','FalseNegatives']
    model.compile(optimizer=opt3, loss='binary_crossentropy', metrics=met)
    return model



def load_model():
    #loaded_model = tf.keras.models.load_model('tupleTrain.keras', custom_objects={'custom_loss':custom_loss})
    loaded_model = tf.keras.models.load_model('multi_test1.keras')
    met = ['Accuracy','AUC','Precision','Recall','TrueNegatives','TruePositives','FalsePositives','FalseNegatives']
    loaded_model.compile(optimizer=opt3, loss=custom_loss, metrics=met)
    return loaded_model


#TRAIN THE MODEL WITH CUSTOMIZABLE EPOCHS-------------------------------------------------------

epochs = 50

early_stopping = []#EarlyStopping(monitor='Precision', patience=100, mode='max', restore_best_weights=True)

model = build_model()
#loaded_model = load_model()
history = model.fit(X_train, y_train, epochs=epochs, validation_split=0.2,\
                    shuffle=True, verbose=1, validation_data=(X_test, y_test),\
                    class_weight=cw, callbacks=early_stopping)

#EVALUATE THE MODEL AND VISUALIZE RESULTS-------------------------------------------------------

#_, acc = model.evaluate(X_test, y_test)
#print("Accuracy = ", (acc * 100.0), "%")

# LOSS
epochs = range(1, len(history.history['loss']) + 1)
plt.figure(figsize=(12, 6))
plt.plot(epochs, history.history['loss'], 'y', label='Training Loss')
plt.plot(epochs, history.history['val_loss'], 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# ACCURACY
plt.plot(epochs, history.history['Accuracy'], 'y', label='Training acc')
plt.plot(epochs, history.history['val_Accuracy'], 'r', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# AUC
plt.plot(epochs, history.history['AUC'], 'y', label='Training AUC')
plt.plot(epochs, history.history['val_AUC'], 'r', label='Validation AUC')
plt.title('Training and Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC Score')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# PRECISION
plt.plot(epochs, history.history['Precision'], 'y', label='Training Precision')
plt.plot(epochs, history.history['val_Precision'], 'r', label='Validation Precision')
plt.title('Training and Validation Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# RECALL
plt.plot(epochs, history.history['Recall'], 'y', label='Training Recall')
plt.plot(epochs, history.history['val_Recall'], 'r', label='Validation Recall')
plt.title('Training and Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# TPR
'''
TPR = history.history['TruePositives']/(history.history['TruePositives']+history.history['TrueNegatives'])
val_TPR = history.history['val_TruePositives']/(history.history['val_TruePositives']+history.history['val_TrueNegatives'])
plt.plot(epochs, TPR, 'y', label='Training TPR')
plt.plot(epochs, val_TPR, 'r', label='Validation TPR')
plt.title('Training and Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('TP Rate')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
'''

#predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

#making a confusion matrix
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d')

# Save the model
#model.save('epoch15k.keras')
# Load the model
#loaded_model = tf.keras.models.load_model('my_model.keras')
# Out:
# TESTED FEATURES:
# Index(['vel5', 'vel10', 'vel15', 'vel30', 'vel60', 'acc5', 'acc10', 'acc15',
#        'acc30', 'acc60', 'stoch12', 'stochDiff6012', 'RSIhl_diff',
#        'RSIhl_diffROC', 'YM_diff', 'NQ_diff', 'FT.1', 'vol', 'vol10', 'vol15',
#        'vol30', 'vol60', 'volD10', 'volD15', 'volD30', 'volD60', 'volDQdiff',
#        'volYMdiff', 'VIX', 'vpm5', 'vpm10', 'vpm15', 'vpm30', 'vpm60', 'FT.2',
#        'ToD', 'DoW'],
#       dtype='object')
# TESTING FOR:
# MOVE
# OCCURANCES IN RAW DATA FOR MOVE:
# {'mv': 4576, 'nm': 3105}
# ins -	 4576
# insMatch -	 4576
# non-ins -	 3105
# PERCENT & WEIGHTS:
# INS	-	83.9270104895105 %
# Non-INS	-	123.68760064412238 %
#
#
# Actual Weights:
# weight_for_0: 0.8392701048951049
# weight_for_1: 1.2368760064412239
# Nin rows size = 67.85402097902097% the size of In rows
#
#
#
# OCCURANCES IN OPT DATA FOR MOVE:
# {'mv': 4576, 'nm': 3105}
# Epoch 1/50
# c:\Users\logan\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - AUC: 0.0092 - Accuracy: 0.5822 - FalseNegatives: 1247.3213 - FalsePositives: 29.9171 - Precision: 0.3621 - Recall: 0.0383 - TrueNegatives: 1809.6270 - TruePositives: 16.9689 - auc_4: 0.0169 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 2/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5906 - FalseNegatives: 1263.8497 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1839.9845 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 3/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5913 - FalseNegatives: 1266.5492 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1837.2850 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 4/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5943 - FalseNegatives: 1251.6217 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1852.2124 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 5/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5984 - FalseNegatives: 1258.4146 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1845.4197 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 6/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5919 - FalseNegatives: 1264.6840 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1839.1503 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 7/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5880 - FalseNegatives: 1272.6011 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1831.2332 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 8/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5954 - FalseNegatives: 1261.6166 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1842.2177 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 9/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5924 - FalseNegatives: 1259.3938 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1844.4404 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 10/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5962 - FalseNegatives: 1253.5078 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1850.3264 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 11/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5865 - FalseNegatives: 1267.8031 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1836.0311 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 12/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.6026 - FalseNegatives: 1258.0104 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1845.8239 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 13/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5991 - FalseNegatives: 1251.9067 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1851.9275 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 14/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5941 - FalseNegatives: 1266.2590 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1837.5751 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 15/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5878 - FalseNegatives: 1274.3575 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1829.4767 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 16/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5968 - FalseNegatives: 1248.2694 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1855.5648 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 17/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5900 - FalseNegatives: 1262.5958 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1841.2383 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 18/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5997 - FalseNegatives: 1255.0829 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1848.7513 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 19/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5926 - FalseNegatives: 1260.0208 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1843.8135 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 20/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5956 - FalseNegatives: 1253.7047 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1850.1295 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 21/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5915 - FalseNegatives: 1263.8652 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1839.9689 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 22/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5945 - FalseNegatives: 1251.7772 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1852.0570 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 23/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5957 - FalseNegatives: 1255.1348 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1848.6995 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 24/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5924 - FalseNegatives: 1257.9637 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1845.8705 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 25/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5961 - FalseNegatives: 1251.6425 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1852.1917 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 26/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5878 - FalseNegatives: 1285.0778 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1818.7565 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 27/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5992 - FalseNegatives: 1245.4612 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1858.3730 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 28/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5943 - FalseNegatives: 1258.4146 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1845.4197 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 29/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5767 - FalseNegatives: 1279.5026 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1824.3317 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 30/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5964 - FalseNegatives: 1259.6115 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1844.2228 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 31/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5962 - FalseNegatives: 1256.5699 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1847.2643 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 32/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5987 - FalseNegatives: 1242.1140 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1861.7202 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 33/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5948 - FalseNegatives: 1253.0518 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1850.7823 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 34/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5895 - FalseNegatives: 1262.1503 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1841.6840 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 35/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.6022 - FalseNegatives: 1245.6632 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1858.1710 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 36/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5936 - FalseNegatives: 1267.2902 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1836.5441 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 37/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5938 - FalseNegatives: 1260.2850 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1843.5492 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 38/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5999 - FalseNegatives: 1256.5803 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1847.2539 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 39/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5936 - FalseNegatives: 1270.4093 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1833.4249 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 40/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5979 - FalseNegatives: 1257.3575 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1846.4767 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 41/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5896 - FalseNegatives: 1273.5596 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1830.2747 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 42/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.6022 - FalseNegatives: 1250.9222 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1852.9119 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 43/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5926 - FalseNegatives: 1261.7565 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1842.0778 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 44/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5986 - FalseNegatives: 1258.3938 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1845.4404 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 45/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5938 - FalseNegatives: 1254.9326 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1848.9016 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 46/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5908 - FalseNegatives: 1270.4974 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1833.3368 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 47/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5953 - FalseNegatives: 1250.6840 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1853.1503 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 48/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5964 - FalseNegatives: 1260.3834 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1843.4508 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 49/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5904 - FalseNegatives: 1264.7668 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1839.0674 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# Epoch 50/50
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - AUC: 0.0000e+00 - Accuracy: 0.5871 - FalseNegatives: 1268.0104 - FalsePositives: 0.0000e+00 - Precision: 0.0000e+00 - Recall: 0.0000e+00 - TrueNegatives: 1835.8239 - TruePositives: 0.0000e+00 - auc_4: 0.0000e+00 - loss: nan - val_AUC: 0.0000e+00 - val_Accuracy: 0.6031 - val_FalseNegatives: 610.0000 - val_FalsePositives: 0.0000e+00 - val_Precision: 0.0000e+00 - val_Recall: 0.0000e+00 - val_TrueNegatives: 927.0000 - val_TruePositives: 0.0000e+00 - val_auc_4: 0.0000e+00 - val_loss: nan
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# <Axes: >

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
TP = history.history['TruePositives'][-1]
FP = history.history['FalsePositives'][-1]
TN = history.history['TrueNegatives'][-1]
FN = history.history['FalseNegatives'][-1]
weight_for_0 = (1 / TN) * ((TN+FN) / 4.0)
weight_for_1 = (1 / TP) * ((TP+FP) / 1.0)

weights_for_0 = data.size/(inRows.size*2)
weights_for_1 = data.size/(inRows.size*2)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: ',(weight_for_0))
print('Weight for class 1: ',(weight_for_1))

print(TP)
print(FP)
# Out:
# Weight for class 0:  0.2829852636075177
# Weight for class 1:  1.5567542725389085
# 128378.0
# 71475.0

# %%
model.save('modData1.keras')

# %%
''' Testing outputs for model (placed here so we don't have to retrain)'''
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.4)

#making a confusion matrix
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d')
# Out:
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# <Axes: >
