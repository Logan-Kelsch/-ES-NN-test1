# %%
#JJ McCauley + LOGAN KELSCH 
#TEST NN 1

#IMPORT LIBRARIES-------------------------------------------------------

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from keras.optimizers import SGD
from keras.initializers import GlorotUniform
from keras.initializers import RandomNormal
from keras.callbacks import EarlyStopping
from imblearn.over_sampling import SMOTE

#hahaha dont turn this on with high epoch or else
#tf.config.experimental.set_memory_growth

#LOAD DATA FROM CSV-------------------------------------------------------

# Load the dataset
data = pd.read_csv('NEED_TO_APPEND.csv')

#testing random feature drops
data = data.drop(columns='FT')
#data = data.drop(columns='FullK')
#data = data.drop(columns='diffKD')
#data = data.drop(columns='OB')
#data = data.drop(columns='OS')
#data = data.drop(columns='vol')
#data = data.drop(columns='s15')
#data = data.drop(columns='s30')
#data = data.drop(columns='s60')
#data = data.drop(columns='ToD')
#data = data.drop(columns='Inertias')
#data = data.drop(columns='percBB')
#data = data.drop(columns='spreadRSI')
#data = data.drop(columns='ADX')
#data = data.drop(columns='RSI')
#data = data.drop(columns='Wpercent')
#data = data.drop(columns='acc')

#TEMP DROP PRE-DUAL-OUTPUT NN

#data = data.drop(columns='bull15')
data = data.drop(columns='bear15')
data = data.drop(columns='bull30')
data = data.drop(columns='bear30')
data = data.drop(columns='bull60')
data = data.drop(columns='bear60')

#confirming X and Y features post training
Xfeatures = data.columns[:-1]
Yfeatures = data.columns[-1]
print("TESTED FEATURES: ")
print(Xfeatures)
print("TESTING FOR: ")
print(Yfeatures)

#DATA OPTIMIZATION------------------------------------------------------

print("OCCURANCES IN RAW DATA FOR ", Yfeatures, ": ", sep='')
unique, counts = np.unique(data.iloc[:, -1].values, return_counts=True)
print(dict(zip(unique,counts)))

#filtering before splitting could be useful if ABSOLUTELY mostly comprised of 'in'
#data = data.drop(data[data['ToD'] > 955].index)
#data = data.drop(data[data['ToD'] < 480].index)

NinRows = data.drop(data[data['bull15'] == 'in'].index)
inRows = data.drop(data[data['bull15'] != 'in'].index)

#CUSTOM DATA FILTERING_____________

#tod >955, <480 - MARKET OPEN
#inRows = inRows.drop(inRows[inRows['ToD'] > 955].index)
#inRows = inRows.drop(inRows[inRows['ToD'] < 455].index)
#inRows = inRows.drop(inRows[inRows['s60'] <0].index)
#inRows = inRows.drop(inRows[inRows['OB'] == 1].index)

#must drop these features in optData!!!!!!!!!!!
#__________________________________

inRowsMatch = inRows#inRows.loc[0:17129]

print('ins -\t',inRows.index.size,'\ninsMatch -\t',\
      inRowsMatch.index.size,'\nnon-ins -\t',NinRows.index.size)

optData = pd.concat([NinRows, inRowsMatch],axis=0)

#optData = optData.drop(columns='s60')
#optData = optData.drop(columns='ToD')
#optData = optData.drop(columns='OB')

percIn = data.size/(inRows.size*2)
percNin = data.size/(NinRows.size*2)
weight_for_0 = percIn
weight_for_1 = percNin
cw = {0: weight_for_0, 1: weight_for_1}

print("PERCENT & WEIGHTS:\nINS\t-\t",percIn*100," %\nNon-INS\t-\t",percNin*100," %",sep='')
print('\n\nActual Weights:\nweight_for_0: ',weight_for_0,'\nweight_for_1: ',weight_for_1,sep='',end='')

print('\nNin rows size = ',(NinRows.size/inRows.size*100),'% the size of In rows\n',sep='')

print("\n\nOCCURANCES IN OPT DATA FOR ", Yfeatures, ": ", sep='')
unique, counts = np.unique(optData.iloc[:, -1].values, return_counts=True)
print(dict(zip(unique,counts)))

#PROCESS THE DATA-------------------------------------------------------

# Separate features and target
X = optData.iloc[:, :-1].values
y = optData.iloc[:, -1].values

#SMOTE OVERSAMPLING________________

#smote = SMOTE()
#X, y = smote.fit_resample(X,y)
#print('\n[PRE-SPLIT] Resampled Data size:',X.size,'--',y.size)

#__________________________________

#Encoding data
labelencoder = LabelBinarizer()
y = labelencoder.fit_transform(y)

# Standardize the features
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) #stratify=y,
#RESAMPLED DATA- POST SPLIT---------------------------------------------------------

#smote = SMOTE()
#X_resampled, y_resampled = smote.fit_resample(X_train,y_train)
#print('\nResampled Data size:',X_resampled.size)

#BUILD THE NEURAL NETWORK MODEL-------------------------------------------------------

from keras.optimizers.schedules import ExponentialDecay
lr_schedule = ExponentialDecay(
    #good rough val to start, .25, good val to end at .0015.
    #5k epoch should be: .25, 8565, .9995, true
    0.01,
    decay_steps=1000,
    decay_rate=0.98,
    staircase=True)

opt1 = SGD(learning_rate=0.0001)
opt2  = tf.keras.optimizers.Adam(clipnorm=0.7)
opt3 = SGD(learning_rate=lr_schedule)

from keras.saving import get_custom_objects
from keras.saving import register_keras_serializable


get_custom_objects().clear()
@register_keras_serializable(name="custom_loss")
def custom_loss(y_true, y_pred):
        
    # Standard binary cross-entropy
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        
    # Define penalties for false negatives (y_true = 1, y_pred = 0)
    false_negatives_penalty = 0.0  # Penalty for false negatives
    false_positives_penalty = 0.0  # Penalty for false positives
        
    # Define reward for true positives (y_true = 1, y_pred = 1)
    true_positives_reward = -0.0  # Negative value to reduce the loss when TP happens

    # Calculate false negatives and false positives
    false_negatives = y_true * (1 - y_pred)
    false_positives = (1 - y_true) * y_pred
        
    # Calculate true positives
    true_positives = y_true * y_pred
        
    # Apply penalties and rewards
    penalties = false_negatives_penalty * false_negatives + false_positives_penalty * false_positives
    rewards = true_positives_reward * true_positives
        
    # Return combined loss (penalize FNs and FPs, reward TPs)
    return bce + penalties + rewards

def build_model():
    model = tf.keras.Sequential([#currently 17 total features
        tf.keras.layers.Dense(512, input_dim=16, activation='leaky_relu'),
        tf.keras.layers.Dropout(0.20),
        tf.keras.layers.Dense(512, activation='leaky_relu'),
        tf.keras.layers.Dropout(0.20),
        tf.keras.layers.Dense(512, activation='leaky_relu'),
        tf.keras.layers.Dropout(0.20),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    AUC=tf.keras.metrics.AUC(curve='PR')
    met = ['Accuracy','AUC',AUC,'Precision','Recall','TrueNegatives','TruePositives','FalsePositives','FalseNegatives']
    model.compile(optimizer=opt3, loss='binary_crossentropy', metrics=met)
    return model



def load_model():
    #loaded_model = tf.keras.models.load_model('tupleTrain.keras', custom_objects={'custom_loss':custom_loss})
    loaded_model = tf.keras.models.load_model('acc77.keras')
    met = ['Accuracy','AUC','Precision','Recall','TrueNegatives','TruePositives','FalsePositives','FalseNegatives']
    loaded_model.compile(optimizer=opt3, loss=custom_loss, metrics=met)
    return loaded_model


#TRAIN THE MODEL WITH CUSTOMIZABLE EPOCHS-------------------------------------------------------

epochs = 50

early_stopping = []#EarlyStopping(monitor='Precision', patience=100, mode='max', restore_best_weights=True)

model = build_model()
loaded_model = load_model()
history = model.fit(X_train, y_train, epochs=epochs, validation_split=0.2,\
                    shuffle=True, verbose=1, validation_data=(X_test, y_test),\
                    class_weight=cw, callbacks=early_stopping)

#EVALUATE THE MODEL AND VISUALIZE RESULTS-------------------------------------------------------

#_, acc = model.evaluate(X_test, y_test)
#print("Accuracy = ", (acc * 100.0), "%")

# LOSS
epochs = range(1, len(history.history['loss']) + 1)
plt.figure(figsize=(12, 6))
plt.plot(epochs, history.history['loss'], 'y', label='Training Loss')
plt.plot(epochs, history.history['val_loss'], 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# ACCURACY
plt.plot(epochs, history.history['Accuracy'], 'y', label='Training acc')
plt.plot(epochs, history.history['val_Accuracy'], 'r', label='Validation acc')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# AUC
plt.plot(epochs, history.history['AUC'], 'y', label='Training AUC')
plt.plot(epochs, history.history['val_AUC'], 'r', label='Validation AUC')
plt.title('Training and Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC Score')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# PRECISION
plt.plot(epochs, history.history['Precision'], 'y', label='Training Precision')
plt.plot(epochs, history.history['val_Precision'], 'r', label='Validation Precision')
plt.title('Training and Validation Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# RECALL
plt.plot(epochs, history.history['Recall'], 'y', label='Training Recall')
plt.plot(epochs, history.history['val_Recall'], 'r', label='Validation Recall')
plt.title('Training and Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# TPR
'''
TPR = history.history['TruePositives']/(history.history['TruePositives']+history.history['TrueNegatives'])
val_TPR = history.history['val_TruePositives']/(history.history['val_TruePositives']+history.history['val_TrueNegatives'])
plt.plot(epochs, TPR, 'y', label='Training TPR')
plt.plot(epochs, val_TPR, 'r', label='Validation TPR')
plt.title('Training and Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('TP Rate')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
'''

#predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

#making a confusion matrix
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d')

# Save the model
#model.save('epoch15k.keras')
# Load the model
#loaded_model = tf.keras.models.load_model('my_model.keras')
# Out:
# TESTED FEATURES:
# Index(['FullK', 'diffKD', 'OB', 'OS', 'vol', 's15', 's30', 's60', 'ToD',
#        'Inertias', 'percBB', 'spreadRSI', 'ADX', 'RSI', 'Wpercent', 'acc'],
#       dtype='object')
# TESTING FOR:
# bull15
# OCCURANCES IN RAW DATA FOR bull15:
# {'in': 23257, 'up': 2443}
# ins -	 23257
# insMatch -	 23257
# non-ins -	 2443
# PERCENT & WEIGHTS:
# INS	-	55.25218213871093 %
# Non-INS	-	525.992632009824 %
#
#
# Actual Weights:
# weight_for_0: 0.5525218213871093
# weight_for_1: 5.25992632009824
# Nin rows size = 10.504364277421852% the size of In rows
#
#
#
# OCCURANCES IN OPT DATA FOR bull15:
# {'in': 23257, 'up': 2443}
# Epoch 1/50
# c:\Users\logan\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - AUC: 0.5810 - Accuracy: 0.5612 - FalseNegatives: 406.3727 - FalsePositives: 4170.5791 - Precision: 0.1173 - Recall: 0.5518 - TrueNegatives: 5157.9473 - TruePositives: 585.0015 - auc_6: 0.1254 - loss: 0.6873 - val_AUC: 0.6323 - val_Accuracy: 0.5340 - val_FalseNegatives: 154.0000 - val_FalsePositives: 2241.0000 - val_Precision: 0.1277 - val_Recall: 0.6805 - val_TrueNegatives: 2417.0000 - val_TruePositives: 328.0000 - val_auc_6: 0.1352 - val_loss: 0.6882
# Epoch 2/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6384 - Accuracy: 0.5783 - FalseNegatives: 376.7252 - FalsePositives: 3935.8586 - Precision: 0.1298 - Recall: 0.6128 - TrueNegatives: 5414.3760 - TruePositives: 592.9410 - auc_6: 0.1487 - loss: 0.6599 - val_AUC: 0.6368 - val_Accuracy: 0.5389 - val_FalseNegatives: 150.0000 - val_FalsePositives: 2220.0000 - val_Precision: 0.1301 - val_Recall: 0.6888 - val_TrueNegatives: 2438.0000 - val_TruePositives: 332.0000 - val_auc_6: 0.1385 - val_loss: 0.6824
# Epoch 3/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6369 - Accuracy: 0.5418 - FalseNegatives: 331.0373 - FalsePositives: 4299.0605 - Precision: 0.1351 - Recall: 0.6759 - TrueNegatives: 5022.0806 - TruePositives: 667.7220 - auc_6: 0.1552 - loss: 0.6741 - val_AUC: 0.6388 - val_Accuracy: 0.5702 - val_FalseNegatives: 165.0000 - val_FalsePositives: 2044.0000 - val_Precision: 0.1343 - val_Recall: 0.6577 - val_TrueNegatives: 2614.0000 - val_TruePositives: 317.0000 - val_auc_6: 0.1423 - val_loss: 0.6542
# Epoch 4/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6361 - Accuracy: 0.5495 - FalseNegatives: 336.0839 - FalsePositives: 4227.5483 - Precision: 0.1356 - Recall: 0.6584 - TrueNegatives: 5092.2314 - TruePositives: 664.0373 - auc_6: 0.1568 - loss: 0.6765 - val_AUC: 0.6444 - val_Accuracy: 0.5848 - val_FalseNegatives: 167.0000 - val_FalsePositives: 1967.0000 - val_Precision: 0.1380 - val_Recall: 0.6535 - val_TrueNegatives: 2691.0000 - val_TruePositives: 315.0000 - val_auc_6: 0.1452 - val_loss: 0.6435
# Epoch 5/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6466 - Accuracy: 0.5781 - FalseNegatives: 345.0528 - FalsePositives: 4079.2888 - Precision: 0.1364 - Recall: 0.6420 - TrueNegatives: 5253.2300 - TruePositives: 642.3292 - auc_6: 0.1531 - loss: 0.6615 - val_AUC: 0.6475 - val_Accuracy: 0.5698 - val_FalseNegatives: 155.0000 - val_FalsePositives: 2056.0000 - val_Precision: 0.1372 - val_Recall: 0.6784 - val_TrueNegatives: 2602.0000 - val_TruePositives: 327.0000 - val_auc_6: 0.1468 - val_loss: 0.6517
# Epoch 6/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6542 - Accuracy: 0.5928 - FalseNegatives: 340.6289 - FalsePositives: 3993.9146 - Precision: 0.1358 - Recall: 0.6408 - TrueNegatives: 5359.5078 - TruePositives: 625.8494 - auc_6: 0.1519 - loss: 0.6455 - val_AUC: 0.6500 - val_Accuracy: 0.5335 - val_FalseNegatives: 141.0000 - val_FalsePositives: 2257.0000 - val_Precision: 0.1313 - val_Recall: 0.7075 - val_TrueNegatives: 2401.0000 - val_TruePositives: 341.0000 - val_auc_6: 0.1467 - val_loss: 0.6807
# Epoch 7/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6538 - Accuracy: 0.5510 - FalseNegatives: 326.6537 - FalsePositives: 4179.9175 - Precision: 0.1371 - Recall: 0.6767 - TrueNegatives: 5149.1616 - TruePositives: 664.1677 - auc_6: 0.1586 - loss: 0.6644 - val_AUC: 0.6507 - val_Accuracy: 0.5496 - val_FalseNegatives: 156.0000 - val_FalsePositives: 2159.0000 - val_Precision: 0.1312 - val_Recall: 0.6763 - val_TrueNegatives: 2499.0000 - val_TruePositives: 326.0000 - val_auc_6: 0.1492 - val_loss: 0.6651
# Epoch 8/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6597 - Accuracy: 0.5726 - FalseNegatives: 310.5869 - FalsePositives: 4119.7515 - Precision: 0.1439 - Recall: 0.6935 - TrueNegatives: 5214.8105 - TruePositives: 674.7515 - auc_6: 0.1610 - loss: 0.6565 - val_AUC: 0.6533 - val_Accuracy: 0.5603 - val_FalseNegatives: 161.0000 - val_FalsePositives: 2099.0000 - val_Precision: 0.1326 - val_Recall: 0.6660 - val_TrueNegatives: 2559.0000 - val_TruePositives: 321.0000 - val_auc_6: 0.1513 - val_loss: 0.6571
# Epoch 9/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6676 - Accuracy: 0.5806 - FalseNegatives: 322.4984 - FalsePositives: 3994.0203 - Precision: 0.1425 - Recall: 0.6769 - TrueNegatives: 5351.8291 - TruePositives: 651.5528 - auc_6: 0.1696 - loss: 0.6502 - val_AUC: 0.6534 - val_Accuracy: 0.5432 - val_FalseNegatives: 142.0000 - val_FalsePositives: 2206.0000 - val_Precision: 0.1335 - val_Recall: 0.7054 - val_TrueNegatives: 2452.0000 - val_TruePositives: 340.0000 - val_auc_6: 0.1505 - val_loss: 0.6759
# Epoch 10/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6516 - Accuracy: 0.5621 - FalseNegatives: 317.9425 - FalsePositives: 4184.4971 - Precision: 0.1374 - Recall: 0.6771 - TrueNegatives: 5155.0015 - TruePositives: 662.4597 - auc_6: 0.1632 - loss: 0.6579 - val_AUC: 0.6544 - val_Accuracy: 0.5671 - val_FalseNegatives: 156.0000 - val_FalsePositives: 2069.0000 - val_Precision: 0.1361 - val_Recall: 0.6763 - val_TrueNegatives: 2589.0000 - val_TruePositives: 326.0000 - val_auc_6: 0.1514 - val_loss: 0.6545
# Epoch 11/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6573 - Accuracy: 0.5475 - FalseNegatives: 318.7252 - FalsePositives: 4272.7251 - Precision: 0.1449 - Recall: 0.6895 - TrueNegatives: 5023.0200 - TruePositives: 705.4301 - auc_6: 0.1824 - loss: 0.6804 - val_AUC: 0.6545 - val_Accuracy: 0.6105 - val_FalseNegatives: 177.0000 - val_FalsePositives: 1825.0000 - val_Precision: 0.1432 - val_Recall: 0.6328 - val_TrueNegatives: 2833.0000 - val_TruePositives: 305.0000 - val_auc_6: 0.1532 - val_loss: 0.6248
# Epoch 12/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6708 - Accuracy: 0.5965 - FalseNegatives: 323.3369 - FalsePositives: 3924.0574 - Precision: 0.1446 - Recall: 0.6593 - TrueNegatives: 5414.1709 - TruePositives: 658.3354 - auc_6: 0.1633 - loss: 0.6469 - val_AUC: 0.6596 - val_Accuracy: 0.5881 - val_FalseNegatives: 168.0000 - val_FalsePositives: 1949.0000 - val_Precision: 0.1388 - val_Recall: 0.6515 - val_TrueNegatives: 2709.0000 - val_TruePositives: 314.0000 - val_auc_6: 0.1561 - val_loss: 0.6386
# Epoch 13/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6652 - Accuracy: 0.5996 - FalseNegatives: 335.2717 - FalsePositives: 3930.4722 - Precision: 0.1390 - Recall: 0.6387 - TrueNegatives: 5401.4194 - TruePositives: 652.7375 - auc_6: 0.1643 - loss: 0.6431 - val_AUC: 0.6570 - val_Accuracy: 0.5874 - val_FalseNegatives: 171.0000 - val_FalsePositives: 1950.0000 - val_Precision: 0.1375 - val_Recall: 0.6452 - val_TrueNegatives: 2708.0000 - val_TruePositives: 311.0000 - val_auc_6: 0.1551 - val_loss: 0.6415
# Epoch 14/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6720 - Accuracy: 0.5794 - FalseNegatives: 301.2997 - FalsePositives: 4090.4441 - Precision: 0.1469 - Recall: 0.6982 - TrueNegatives: 5230.8105 - TruePositives: 697.3463 - auc_6: 0.1703 - loss: 0.6513 - val_AUC: 0.6579 - val_Accuracy: 0.6214 - val_FalseNegatives: 188.0000 - val_FalsePositives: 1758.0000 - val_Precision: 0.1433 - val_Recall: 0.6100 - val_TrueNegatives: 2900.0000 - val_TruePositives: 294.0000 - val_auc_6: 0.1556 - val_loss: 0.6219
# Epoch 15/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6742 - Accuracy: 0.5821 - FalseNegatives: 320.6320 - FalsePositives: 4041.1880 - Precision: 0.1497 - Recall: 0.6806 - TrueNegatives: 5275.0122 - TruePositives: 683.0683 - auc_6: 0.1764 - loss: 0.6560 - val_AUC: 0.6607 - val_Accuracy: 0.5914 - val_FalseNegatives: 164.0000 - val_FalsePositives: 1936.0000 - val_Precision: 0.1411 - val_Recall: 0.6598 - val_TrueNegatives: 2722.0000 - val_TruePositives: 318.0000 - val_auc_6: 0.1561 - val_loss: 0.6438
# Epoch 16/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6716 - Accuracy: 0.5856 - FalseNegatives: 315.2655 - FalsePositives: 3998.1243 - Precision: 0.1466 - Recall: 0.6772 - TrueNegatives: 5321.3384 - TruePositives: 685.1724 - auc_6: 0.1722 - loss: 0.6512 - val_AUC: 0.6607 - val_Accuracy: 0.5671 - val_FalseNegatives: 153.0000 - val_FalsePositives: 2072.0000 - val_Precision: 0.1370 - val_Recall: 0.6826 - val_TrueNegatives: 2586.0000 - val_TruePositives: 329.0000 - val_auc_6: 0.1564 - val_loss: 0.6594
# Epoch 17/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6817 - Accuracy: 0.5887 - FalseNegatives: 306.9627 - FalsePositives: 3931.8245 - Precision: 0.1497 - Recall: 0.6989 - TrueNegatives: 5405.2905 - TruePositives: 675.8230 - auc_6: 0.1783 - loss: 0.6448 - val_AUC: 0.6621 - val_Accuracy: 0.5156 - val_FalseNegatives: 117.0000 - val_FalsePositives: 2373.0000 - val_Precision: 0.1333 - val_Recall: 0.7573 - val_TrueNegatives: 2285.0000 - val_TruePositives: 365.0000 - val_auc_6: 0.1557 - val_loss: 0.7044
# Epoch 18/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6772 - Accuracy: 0.5799 - FalseNegatives: 300.0559 - FalsePositives: 4062.0481 - Precision: 0.1434 - Recall: 0.6990 - TrueNegatives: 5267.1240 - TruePositives: 690.6724 - auc_6: 0.1696 - loss: 0.6385 - val_AUC: 0.6608 - val_Accuracy: 0.5866 - val_FalseNegatives: 165.0000 - val_FalsePositives: 1960.0000 - val_Precision: 0.1392 - val_Recall: 0.6577 - val_TrueNegatives: 2698.0000 - val_TruePositives: 317.0000 - val_auc_6: 0.1583 - val_loss: 0.6445
# Epoch 19/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6710 - Accuracy: 0.5776 - FalseNegatives: 304.3975 - FalsePositives: 4135.6182 - Precision: 0.1488 - Recall: 0.6943 - TrueNegatives: 5169.1226 - TruePositives: 710.7625 - auc_6: 0.1760 - loss: 0.6563 - val_AUC: 0.6582 - val_Accuracy: 0.6023 - val_FalseNegatives: 166.0000 - val_FalsePositives: 1878.0000 - val_Precision: 0.1440 - val_Recall: 0.6556 - val_TrueNegatives: 2780.0000 - val_TruePositives: 316.0000 - val_auc_6: 0.1547 - val_loss: 0.6384
# Epoch 20/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6584 - Accuracy: 0.5825 - FalseNegatives: 316.6832 - FalsePositives: 4053.9456 - Precision: 0.1424 - Recall: 0.6715 - TrueNegatives: 5271.4800 - TruePositives: 677.7919 - auc_6: 0.1656 - loss: 0.6538 - val_AUC: 0.6598 - val_Accuracy: 0.5842 - val_FalseNegatives: 167.0000 - val_FalsePositives: 1970.0000 - val_Precision: 0.1379 - val_Recall: 0.6535 - val_TrueNegatives: 2688.0000 - val_TruePositives: 315.0000 - val_auc_6: 0.1560 - val_loss: 0.6461
# Epoch 21/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6812 - Accuracy: 0.6091 - FalseNegatives: 318.8323 - FalsePositives: 3763.7671 - Precision: 0.1497 - Recall: 0.6809 - TrueNegatives: 5588.5293 - TruePositives: 648.7717 - auc_6: 0.1771 - loss: 0.6347 - val_AUC: 0.6618 - val_Accuracy: 0.5492 - val_FalseNegatives: 139.0000 - val_FalsePositives: 2178.0000 - val_Precision: 0.1361 - val_Recall: 0.7116 - val_TrueNegatives: 2480.0000 - val_TruePositives: 343.0000 - val_auc_6: 0.1587 - val_loss: 0.6717
# Epoch 22/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6713 - Accuracy: 0.5850 - FalseNegatives: 307.7500 - FalsePositives: 3996.4363 - Precision: 0.1420 - Recall: 0.6803 - TrueNegatives: 5346.7642 - TruePositives: 668.9503 - auc_6: 0.1703 - loss: 0.6412 - val_AUC: 0.6608 - val_Accuracy: 0.5440 - val_FalseNegatives: 136.0000 - val_FalsePositives: 2208.0000 - val_Precision: 0.1355 - val_Recall: 0.7178 - val_TrueNegatives: 2450.0000 - val_TruePositives: 346.0000 - val_auc_6: 0.1561 - val_loss: 0.6795
# Epoch 23/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6678 - Accuracy: 0.5746 - FalseNegatives: 311.0078 - FalsePositives: 4038.7236 - Precision: 0.1439 - Recall: 0.6884 - TrueNegatives: 5286.9424 - TruePositives: 683.2267 - auc_6: 0.1773 - loss: 0.6505 - val_AUC: 0.6614 - val_Accuracy: 0.5562 - val_FalseNegatives: 148.0000 - val_FalsePositives: 2133.0000 - val_Precision: 0.1354 - val_Recall: 0.6929 - val_TrueNegatives: 2525.0000 - val_TruePositives: 334.0000 - val_auc_6: 0.1570 - val_loss: 0.6658
# Epoch 24/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6833 - Accuracy: 0.5871 - FalseNegatives: 301.8867 - FalsePositives: 3974.9519 - Precision: 0.1510 - Recall: 0.7038 - TrueNegatives: 5348.6553 - TruePositives: 694.4069 - auc_6: 0.1768 - loss: 0.6447 - val_AUC: 0.6652 - val_Accuracy: 0.5595 - val_FalseNegatives: 147.0000 - val_FalsePositives: 2117.0000 - val_Precision: 0.1366 - val_Recall: 0.6950 - val_TrueNegatives: 2541.0000 - val_TruePositives: 335.0000 - val_auc_6: 0.1605 - val_loss: 0.6606
# Epoch 25/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6841 - Accuracy: 0.5985 - FalseNegatives: 306.3758 - FalsePositives: 3900.5061 - Precision: 0.1458 - Recall: 0.6847 - TrueNegatives: 5444.6675 - TruePositives: 668.3510 - auc_6: 0.1743 - loss: 0.6311 - val_AUC: 0.6602 - val_Accuracy: 0.5337 - val_FalseNegatives: 135.0000 - val_FalsePositives: 2262.0000 - val_Precision: 0.1330 - val_Recall: 0.7199 - val_TrueNegatives: 2396.0000 - val_TruePositives: 347.0000 - val_auc_6: 0.1567 - val_loss: 0.6866
# Epoch 26/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6654 - Accuracy: 0.5697 - FalseNegatives: 304.0264 - FalsePositives: 4057.7949 - Precision: 0.1418 - Recall: 0.6878 - TrueNegatives: 5283.8135 - TruePositives: 674.2655 - auc_6: 0.1685 - loss: 0.6494 - val_AUC: 0.6630 - val_Accuracy: 0.5457 - val_FalseNegatives: 139.0000 - val_FalsePositives: 2196.0000 - val_Precision: 0.1351 - val_Recall: 0.7116 - val_TrueNegatives: 2462.0000 - val_TruePositives: 343.0000 - val_auc_6: 0.1577 - val_loss: 0.6788
# Epoch 27/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6738 - Accuracy: 0.5916 - FalseNegatives: 308.7547 - FalsePositives: 3882.8726 - Precision: 0.1420 - Recall: 0.6742 - TrueNegatives: 5469.7500 - TruePositives: 658.5233 - auc_6: 0.1666 - loss: 0.6367 - val_AUC: 0.6635 - val_Accuracy: 0.5350 - val_FalseNegatives: 124.0000 - val_FalsePositives: 2266.0000 - val_Precision: 0.1364 - val_Recall: 0.7427 - val_TrueNegatives: 2392.0000 - val_TruePositives: 358.0000 - val_auc_6: 0.1583 - val_loss: 0.6876
# Epoch 28/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6834 - Accuracy: 0.5877 - FalseNegatives: 319.2826 - FalsePositives: 3961.1816 - Precision: 0.1419 - Recall: 0.6811 - TrueNegatives: 5380.2563 - TruePositives: 659.1801 - auc_6: 0.1797 - loss: 0.6327 - val_AUC: 0.6630 - val_Accuracy: 0.5741 - val_FalseNegatives: 156.0000 - val_FalsePositives: 2033.0000 - val_Precision: 0.1382 - val_Recall: 0.6763 - val_TrueNegatives: 2625.0000 - val_TruePositives: 326.0000 - val_auc_6: 0.1573 - val_loss: 0.6525
# Epoch 29/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6821 - Accuracy: 0.5866 - FalseNegatives: 314.8727 - FalsePositives: 3963.5559 - Precision: 0.1517 - Recall: 0.6911 - TrueNegatives: 5365.7236 - TruePositives: 675.7485 - auc_6: 0.1860 - loss: 0.6504 - val_AUC: 0.6626 - val_Accuracy: 0.5140 - val_FalseNegatives: 120.0000 - val_FalsePositives: 2378.0000 - val_Precision: 0.1321 - val_Recall: 0.7510 - val_TrueNegatives: 2280.0000 - val_TruePositives: 362.0000 - val_auc_6: 0.1556 - val_loss: 0.7180
# Epoch 30/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6787 - Accuracy: 0.5881 - FalseNegatives: 309.0792 - FalsePositives: 3910.0327 - Precision: 0.1413 - Recall: 0.6828 - TrueNegatives: 5443.1118 - TruePositives: 657.6770 - auc_6: 0.1660 - loss: 0.6321 - val_AUC: 0.6618 - val_Accuracy: 0.5432 - val_FalseNegatives: 142.0000 - val_FalsePositives: 2206.0000 - val_Precision: 0.1335 - val_Recall: 0.7054 - val_TrueNegatives: 2452.0000 - val_TruePositives: 340.0000 - val_auc_6: 0.1563 - val_loss: 0.6796
# Epoch 31/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6779 - Accuracy: 0.5949 - FalseNegatives: 317.3944 - FalsePositives: 3869.2625 - Precision: 0.1406 - Recall: 0.6642 - TrueNegatives: 5482.1460 - TruePositives: 651.0978 - auc_6: 0.1746 - loss: 0.6316 - val_AUC: 0.6654 - val_Accuracy: 0.5200 - val_FalseNegatives: 121.0000 - val_FalsePositives: 2346.0000 - val_Precision: 0.1334 - val_Recall: 0.7490 - val_TrueNegatives: 2312.0000 - val_TruePositives: 361.0000 - val_auc_6: 0.1587 - val_loss: 0.7007
# Epoch 32/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6805 - Accuracy: 0.5725 - FalseNegatives: 302.7764 - FalsePositives: 4079.7097 - Precision: 0.1456 - Recall: 0.7026 - TrueNegatives: 5248.0000 - TruePositives: 689.4146 - auc_6: 0.1858 - loss: 0.6445 - val_AUC: 0.6643 - val_Accuracy: 0.5669 - val_FalseNegatives: 155.0000 - val_FalsePositives: 2071.0000 - val_Precision: 0.1364 - val_Recall: 0.6784 - val_TrueNegatives: 2587.0000 - val_TruePositives: 327.0000 - val_auc_6: 0.1594 - val_loss: 0.6588
# Epoch 33/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6814 - Accuracy: 0.5927 - FalseNegatives: 312.1817 - FalsePositives: 3902.4099 - Precision: 0.1477 - Recall: 0.6800 - TrueNegatives: 5427.6489 - TruePositives: 677.6599 - auc_6: 0.1763 - loss: 0.6411 - val_AUC: 0.6606 - val_Accuracy: 0.5481 - val_FalseNegatives: 137.0000 - val_FalsePositives: 2186.0000 - val_Precision: 0.1363 - val_Recall: 0.7158 - val_TrueNegatives: 2472.0000 - val_TruePositives: 345.0000 - val_auc_6: 0.1577 - val_loss: 0.6775
# Epoch 34/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6821 - Accuracy: 0.5992 - FalseNegatives: 301.9488 - FalsePositives: 3870.2610 - Precision: 0.1473 - Recall: 0.6888 - TrueNegatives: 5469.0464 - TruePositives: 678.6444 - auc_6: 0.1760 - loss: 0.6316 - val_AUC: 0.6650 - val_Accuracy: 0.5706 - val_FalseNegatives: 153.0000 - val_FalsePositives: 2054.0000 - val_Precision: 0.1381 - val_Recall: 0.6826 - val_TrueNegatives: 2604.0000 - val_TruePositives: 329.0000 - val_auc_6: 0.1600 - val_loss: 0.6563
# Epoch 35/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6867 - Accuracy: 0.6108 - FalseNegatives: 314.2826 - FalsePositives: 3788.0715 - Precision: 0.1499 - Recall: 0.6773 - TrueNegatives: 5553.9272 - TruePositives: 663.6196 - auc_6: 0.1735 - loss: 0.6323 - val_AUC: 0.6647 - val_Accuracy: 0.5831 - val_FalseNegatives: 156.0000 - val_FalsePositives: 1987.0000 - val_Precision: 0.1409 - val_Recall: 0.6763 - val_TrueNegatives: 2671.0000 - val_TruePositives: 326.0000 - val_auc_6: 0.1592 - val_loss: 0.6472
# Epoch 36/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6816 - Accuracy: 0.6047 - FalseNegatives: 317.6677 - FalsePositives: 3832.8896 - Precision: 0.1468 - Recall: 0.6710 - TrueNegatives: 5510.6567 - TruePositives: 658.6863 - auc_6: 0.1745 - loss: 0.6336 - val_AUC: 0.6631 - val_Accuracy: 0.5412 - val_FalseNegatives: 134.0000 - val_FalsePositives: 2224.0000 - val_Precision: 0.1353 - val_Recall: 0.7220 - val_TrueNegatives: 2434.0000 - val_TruePositives: 348.0000 - val_auc_6: 0.1575 - val_loss: 0.6829
# Epoch 37/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6801 - Accuracy: 0.5876 - FalseNegatives: 319.2811 - FalsePositives: 3945.3184 - Precision: 0.1401 - Recall: 0.6630 - TrueNegatives: 5391.9194 - TruePositives: 663.3820 - auc_6: 0.1764 - loss: 0.6331 - val_AUC: 0.6634 - val_Accuracy: 0.5257 - val_FalseNegatives: 126.0000 - val_FalsePositives: 2312.0000 - val_Precision: 0.1334 - val_Recall: 0.7386 - val_TrueNegatives: 2346.0000 - val_TruePositives: 356.0000 - val_auc_6: 0.1584 - val_loss: 0.6993
# Epoch 38/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6865 - Accuracy: 0.5879 - FalseNegatives: 297.5435 - FalsePositives: 3926.4316 - Precision: 0.1483 - Recall: 0.7010 - TrueNegatives: 5410.4893 - TruePositives: 685.4363 - auc_6: 0.1827 - loss: 0.6355 - val_AUC: 0.6643 - val_Accuracy: 0.5504 - val_FalseNegatives: 139.0000 - val_FalsePositives: 2172.0000 - val_Precision: 0.1364 - val_Recall: 0.7116 - val_TrueNegatives: 2486.0000 - val_TruePositives: 343.0000 - val_auc_6: 0.1596 - val_loss: 0.6779
# Epoch 39/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6774 - Accuracy: 0.5726 - FalseNegatives: 313.1599 - FalsePositives: 4020.1133 - Precision: 0.1430 - Recall: 0.6807 - TrueNegatives: 5302.1318 - TruePositives: 684.4954 - auc_6: 0.1857 - loss: 0.6467 - val_AUC: 0.6644 - val_Accuracy: 0.5737 - val_FalseNegatives: 151.0000 - val_FalsePositives: 2040.0000 - val_Precision: 0.1396 - val_Recall: 0.6867 - val_TrueNegatives: 2618.0000 - val_TruePositives: 331.0000 - val_auc_6: 0.1586 - val_loss: 0.6582
# Epoch 40/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6844 - Accuracy: 0.6000 - FalseNegatives: 307.1460 - FalsePositives: 3846.9238 - Precision: 0.1510 - Recall: 0.6882 - TrueNegatives: 5483.9365 - TruePositives: 681.8944 - auc_6: 0.1785 - loss: 0.6398 - val_AUC: 0.6653 - val_Accuracy: 0.5576 - val_FalseNegatives: 145.0000 - val_FalsePositives: 2129.0000 - val_Precision: 0.1367 - val_Recall: 0.6992 - val_TrueNegatives: 2529.0000 - val_TruePositives: 337.0000 - val_auc_6: 0.1598 - val_loss: 0.6689
# Epoch 41/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6875 - Accuracy: 0.5879 - FalseNegatives: 314.6879 - FalsePositives: 3917.8711 - Precision: 0.1485 - Recall: 0.6897 - TrueNegatives: 5410.1382 - TruePositives: 677.2034 - auc_6: 0.1932 - loss: 0.6389 - val_AUC: 0.6653 - val_Accuracy: 0.5619 - val_FalseNegatives: 149.0000 - val_FalsePositives: 2103.0000 - val_Precision: 0.1367 - val_Recall: 0.6909 - val_TrueNegatives: 2555.0000 - val_TruePositives: 333.0000 - val_auc_6: 0.1598 - val_loss: 0.6617
# Epoch 42/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6724 - Accuracy: 0.5935 - FalseNegatives: 313.5559 - FalsePositives: 3858.4487 - Precision: 0.1469 - Recall: 0.6774 - TrueNegatives: 5480.1865 - TruePositives: 667.7097 - auc_6: 0.1761 - loss: 0.6464 - val_AUC: 0.6660 - val_Accuracy: 0.5492 - val_FalseNegatives: 137.0000 - val_FalsePositives: 2180.0000 - val_Precision: 0.1366 - val_Recall: 0.7158 - val_TrueNegatives: 2478.0000 - val_TruePositives: 345.0000 - val_auc_6: 0.1603 - val_loss: 0.6742
# Epoch 43/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6842 - Accuracy: 0.5935 - FalseNegatives: 300.6382 - FalsePositives: 3846.9534 - Precision: 0.1481 - Recall: 0.6924 - TrueNegatives: 5500.1460 - TruePositives: 672.1630 - auc_6: 0.1753 - loss: 0.6348 - val_AUC: 0.6664 - val_Accuracy: 0.5446 - val_FalseNegatives: 133.0000 - val_FalsePositives: 2208.0000 - val_Precision: 0.1365 - val_Recall: 0.7241 - val_TrueNegatives: 2450.0000 - val_TruePositives: 349.0000 - val_auc_6: 0.1606 - val_loss: 0.6813
# Epoch 44/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6936 - Accuracy: 0.5898 - FalseNegatives: 303.9783 - FalsePositives: 3888.8152 - Precision: 0.1490 - Recall: 0.6940 - TrueNegatives: 5446.2905 - TruePositives: 680.8168 - auc_6: 0.1926 - loss: 0.6339 - val_AUC: 0.6653 - val_Accuracy: 0.5554 - val_FalseNegatives: 141.0000 - val_FalsePositives: 2144.0000 - val_Precision: 0.1372 - val_Recall: 0.7075 - val_TrueNegatives: 2514.0000 - val_TruePositives: 341.0000 - val_auc_6: 0.1590 - val_loss: 0.6692
# Epoch 45/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6821 - Accuracy: 0.5952 - FalseNegatives: 304.2686 - FalsePositives: 3876.8696 - Precision: 0.1455 - Recall: 0.6816 - TrueNegatives: 5474.6567 - TruePositives: 664.1056 - auc_6: 0.1790 - loss: 0.6333 - val_AUC: 0.6642 - val_Accuracy: 0.5270 - val_FalseNegatives: 128.0000 - val_FalsePositives: 2303.0000 - val_Precision: 0.1332 - val_Recall: 0.7344 - val_TrueNegatives: 2355.0000 - val_TruePositives: 354.0000 - val_auc_6: 0.1581 - val_loss: 0.7003
# Epoch 46/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6867 - Accuracy: 0.5944 - FalseNegatives: 304.1397 - FalsePositives: 3870.8882 - Precision: 0.1484 - Recall: 0.6894 - TrueNegatives: 5470.3911 - TruePositives: 674.4814 - auc_6: 0.1898 - loss: 0.6338 - val_AUC: 0.6638 - val_Accuracy: 0.5523 - val_FalseNegatives: 147.0000 - val_FalsePositives: 2154.0000 - val_Precision: 0.1346 - val_Recall: 0.6950 - val_TrueNegatives: 2504.0000 - val_TruePositives: 335.0000 - val_auc_6: 0.1595 - val_loss: 0.6695
# Epoch 47/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6847 - Accuracy: 0.6026 - FalseNegatives: 312.5171 - FalsePositives: 3829.7856 - Precision: 0.1460 - Recall: 0.6739 - TrueNegatives: 5513.5078 - TruePositives: 664.0901 - auc_6: 0.1846 - loss: 0.6304 - val_AUC: 0.6611 - val_Accuracy: 0.5562 - val_FalseNegatives: 147.0000 - val_FalsePositives: 2134.0000 - val_Precision: 0.1357 - val_Recall: 0.6950 - val_TrueNegatives: 2524.0000 - val_TruePositives: 335.0000 - val_auc_6: 0.1576 - val_loss: 0.6725
# Epoch 48/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6976 - Accuracy: 0.5968 - FalseNegatives: 308.3494 - FalsePositives: 3867.9131 - Precision: 0.1545 - Recall: 0.7000 - TrueNegatives: 5453.2451 - TruePositives: 690.3929 - auc_6: 0.1990 - loss: 0.6355 - val_AUC: 0.6648 - val_Accuracy: 0.5689 - val_FalseNegatives: 150.0000 - val_FalsePositives: 2066.0000 - val_Precision: 0.1384 - val_Recall: 0.6888 - val_TrueNegatives: 2592.0000 - val_TruePositives: 332.0000 - val_auc_6: 0.1589 - val_loss: 0.6625
# Epoch 49/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6936 - Accuracy: 0.5988 - FalseNegatives: 305.0839 - FalsePositives: 3860.4844 - Precision: 0.1517 - Recall: 0.6972 - TrueNegatives: 5471.6646 - TruePositives: 682.6677 - auc_6: 0.1925 - loss: 0.6326 - val_AUC: 0.6637 - val_Accuracy: 0.5490 - val_FalseNegatives: 143.0000 - val_FalsePositives: 2175.0000 - val_Precision: 0.1348 - val_Recall: 0.7033 - val_TrueNegatives: 2483.0000 - val_TruePositives: 339.0000 - val_auc_6: 0.1599 - val_loss: 0.6750
# Epoch 50/50
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - AUC: 0.6958 - Accuracy: 0.6031 - FalseNegatives: 304.5869 - FalsePositives: 3826.5110 - Precision: 0.1476 - Recall: 0.6830 - TrueNegatives: 5512.6943 - TruePositives: 676.1087 - auc_6: 0.1823 - loss: 0.6233 - val_AUC: 0.6652 - val_Accuracy: 0.5568 - val_FalseNegatives: 142.0000 - val_FalsePositives: 2136.0000 - val_Precision: 0.1373 - val_Recall: 0.7054 - val_TrueNegatives: 2522.0000 - val_TruePositives: 340.0000 - val_auc_6: 0.1589 - val_loss: 0.6693
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# <Axes: >

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
TP = history.history['TruePositives'][-1]
FP = history.history['FalsePositives'][-1]
TN = history.history['TrueNegatives'][-1]
FN = history.history['FalseNegatives'][-1]
weight_for_0 = (1 / TN) * ((TN+FN) / 4.0)
weight_for_1 = (1 / TP) * ((TP+FP) / 1.0)

weights_for_0 = data.size/(inRows.size*2)
weights_for_1 = data.size/(inRows.size*2)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: ',(weight_for_0))
print('Weight for class 1: ',(weight_for_1))

print(TP)
print(FP)
# Out:
# Weight for class 0:  0.2829852636075177
# Weight for class 1:  1.5567542725389085
# 128378.0
# 71475.0

# %%
model.save('modData1.keras')

# %%
''' Testing outputs for model (placed here so we don't have to retrain)'''
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.4)

#making a confusion matrix
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d')
# Out:
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# <Axes: >
